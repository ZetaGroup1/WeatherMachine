# %%
import pandas as pd
import glob
 
# Load all weather files
file_paths = glob.glob("Data cleaning\Final_merge\Final/*.csv")  # Adjust path
dfs = {file.split("/")[-1]: pd.read_csv(file) for file in file_paths}
df_Himos = pd.read_csv('Data cleaning\Final_merge\Final/Himos_final.csv')
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\F'
# <>:7: SyntaxWarning: invalid escape sequence '\F'
# <>:5: SyntaxWarning: invalid escape sequence '\F'
# <>:7: SyntaxWarning: invalid escape sequence '\F'
# C:\Users\Ilyas Land\AppData\Local\Temp\ipykernel_1740\1568829338.py:5: SyntaxWarning: invalid escape sequence '\F'
#   file_paths = glob.glob("Data cleaning\Final_merge\Final/*.csv")  # Adjust path
# C:\Users\Ilyas Land\AppData\Local\Temp\ipykernel_1740\1568829338.py:7: SyntaxWarning: invalid escape sequence '\F'
#   df_Himos = pd.read_csv('Data cleaning\Final_merge\Final/Himos_final.csv')

# %%
df_Himos
# Out:
#             Date  Precipitation amount [mm]  Snow depth [cm]  \
# 0     2005-01-01                        0.2             16.0
# 1     2005-01-02                        3.1             16.0
# 2     2005-01-03                        0.4             19.0
# 3     2005-01-04                        1.5             20.0
# 4     2005-01-05                        4.3             20.0
# ...          ...                        ...              ...
# 7301  2024-12-28                        0.7             12.0
# 7302  2024-12-29                        6.5             12.0
# 7303  2024-12-30                       -1.0              7.0
# 7304  2024-12-31                       -1.0              8.0
# 7305  2025-01-01                        NaN              NaN
#
#       Average temperature [°C]  cloud_cover_code  \
# 0                         -1.5               0.0
# 1                         -0.3               8.0
# 2                         -0.8               7.0
# ...

# %%
dfs['Data cleaning\\Final_merge\\Final\\Himos_final.csv']
# Out:
#             Date  Precipitation amount [mm]  Snow depth [cm]  \
# 0     2005-01-01                        0.2             16.0
# 1     2005-01-02                        3.1             16.0
# 2     2005-01-03                        0.4             19.0
# 3     2005-01-04                        1.5             20.0
# 4     2005-01-05                        4.3             20.0
# ...          ...                        ...              ...
# 7301  2024-12-28                        0.7             12.0
# 7302  2024-12-29                        6.5             12.0
# 7303  2024-12-30                       -1.0              7.0
# 7304  2024-12-31                       -1.0              8.0
# 7305  2025-01-01                        NaN              NaN
#
#       Average temperature [°C]  cloud_cover_code  \
# 0                         -1.5               0.0
# 1                         -0.3               8.0
# 2                         -0.8               7.0
# ...

# %%
dfs['Data cleaning\\Final_merge\\Final\\Lahti_final.csv']
# Out:
#             Date  cloud_cover_code  Precipitation amount [mm]  \
# 0     2005-01-01               NaN                        0.3
# 1     2005-01-02               NaN                        4.2
# 2     2005-01-03               NaN                        0.8
# 3     2005-01-04               NaN                        1.8
# 4     2005-01-05               NaN                        6.2
# ...          ...               ...                        ...
# 7301  2024-12-28               9.0                        0.5
# 7302  2024-12-29               8.0                        6.4
# 7303  2024-12-30               8.0                       -1.0
# 7304  2024-12-31               0.0                        0.9
# 7305  2025-01-01               NaN                        NaN
#
#       Snow depth [cm]  Average temperature [°C]  \
# 0                15.0                      -1.0
# 1                15.0                       0.2
# 2                19.0                      -1.4
# ...
