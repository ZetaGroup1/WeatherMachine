# %%
import pandas as pd
import os

# %%
df = pd.read_csv('C:\\Repos\\Project2\\WeatherMachine\\Data cleaning\\Test_merge\\Final\\Lahti_final.csv')

df
# Out:
#             Date  Cloud cover [1/8]  cloud_cover_code  \
# 0     2000-01-01                NaN               NaN
# 1     2000-01-02                NaN               NaN
# 2     2000-01-03                NaN               NaN
# 3     2000-01-04                NaN               NaN
# 4     2000-01-05                NaN               NaN
# ...          ...                ...               ...
# 9128  2024-12-28                NaN               9.0
# 9129  2024-12-29                NaN               8.0
# 9130  2024-12-30                NaN               8.0
# 9131  2024-12-31                NaN               0.0
# 9132  2025-01-01                NaN               NaN
#
#       Precipitation amount [mm]  Snow depth [cm]  Average temperature [°C]  \
# 0                           0.4             27.0                     -13.6
# 1                           7.7             26.0                      -4.0
# 2                           1.2             31.0                      -2.4
# ...
